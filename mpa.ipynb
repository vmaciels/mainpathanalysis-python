# %%
import sys

import importlib
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
import mpalib as mpa
import matplotlib.colors as colors
import matplotlib.cm as cmx

importlib.reload(mpa)
# Out:
# <module 'mpalib' from 'c:\\Users\\T-GAMER\\mainpathanalysis-python\\mpalib.py'>

# %%
G=nx.gn_graph(1000)

# %%
pos=nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos=pos,node_size=1)
nx.draw_networkx_edges(G,pos=pos)

# %%
H=mpa.main_path(G,source=mpa.sources(G)[:10])

# %%
nx.draw_networkx_nodes(H,pos=pos,node_size=1)
nx.draw_networkx_edges(H,pos=pos)
